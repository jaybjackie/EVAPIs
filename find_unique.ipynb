# %%
import pandas as pd
import os

# %%
data = []
path = 'output.csv'

# %%
df = pd.read_csv(f'{path}')
df
# Out:
#                    results/description            results/Name_EN  \
# 0        2x CCS2: 160 kW, Type2: 11 kW            Lotus’s Pinklao
# 1        2x CCS2: 160 kW, Type2: 11 kW       Lotus's Sukhapiban 1
# 2     4x CCS2: 150 kW, 2x Type2: 11 kW  Lotus's North Ratchapruek
# 3         2x CCS2: 60 kW, Type2: 11 kW          Lotus's Ang Thong
# 4        2x CCS2: 150 kW, Type2: 11 kW             Lotus's Rojana
# ...                                ...                        ...
# 2126                   2x CCS2: 120 kW                        NaN
# 2127           2x CCS2, Type 2: 120 kW                        NaN
# 2128           2x CCS2, Type 2: 120 kW                        NaN
# 2129           2x CCS2, Type 2: 120 kW                        NaN
# 2130                   2x CCS2: 120 kW                        NaN
#
#                       results/name results/power  \
# 0                  โลตัส ปิ่นเกล้า        160 kW
# 1                โลตัส สุขาภิบาล 1        160 kW
# ...

# %%
df.describe()
# Out:
#        results/latitude  results/longitude  results/evConnectorCount  \
# count       2131.000000        2131.000000                       0.0
# mean          14.008564         100.762062                       NaN
# std            2.424008           1.216427                       NaN
# min            5.770530          97.934235                       NaN
# 25%           13.590790         100.237308                       NaN
# 50%           13.808750         100.575281                       NaN
# 75%           14.886211         101.022219                       NaN
# max           20.427330         105.426253                       NaN
#
#        results/evConnectorAggregation
# count                             0.0
# mean                              NaN
# std                               NaN
# min                               NaN
# 25%                               NaN
# 50%                               NaN
# 75%                               NaN
# ...

# %%
print(df["results/description"].unique())
print(len(df["results/description"].unique()))
# Out:
# ['2x CCS2: 160 kW, Type2: 11 kW' '4x CCS2: 150 kW, 2x Type2: 11 kW'
#  '2x CCS2: 60 kW, Type2: 11 kW' '2x CCS2: 150 kW, Type2: 11 kW'
#  'CCS2: 118 kW, Type2: CLOSED' 'CCS2: 35 kW, Type2: 22 kW'
#  'Type1: 11 kW, Type2: 7x 11 kW, CCS2: 38 kW, CLOSED  B1'
#  'Type2: 22 kW, CCS2: CLOSED' 'Type2: 22 kW, CCS2: 2x 150 kW'
#  'Type1: 22 kW, CLOSED, Type2: 2x 22 kW, CCS2: 40 kW'
#  'Type1: 22 kW, Type2: 22 kW, CCS2: CLOSED' 'CCS2: 40 kW'
#  'CCS2: 2x 118 kW, Type2: CLOSED' 'CCS2: 75 kW, Type2: 22 kW'
#  'Type2: 22 kW, CCS2: 2x 110 kW' 'CCS2: 2x 40 kW, Type2: 22 kW'
#  'Type2: 22 kW, CCS2: 90 kW' 'CCS2: 75 kW, CLOSED'
#  'CCS2: 75 kW, Type2: CLOSED' 'Type2: 5x 11 kW, CCS2: CLOSED'
#  'CCS2: 103 kW, Type2: CLOSED' 'CCS2: 6x 150 kW' 'CCS2: 4x 150 kW'
#  'CCS2: CLOSED, Type2: 11 kW, CLOSED, Type1: CLOSED, -'
#  'CCS2: 2x 110 kW, Type2: CLOSED'
#  'Type1: 22 kW, CLOSED, Type2: 5 kW, CLOSED, CCS2: 90 kW, CLOSED'
#  'Type2: 5 kW, CLOSED, CCS2: 2x 90 kW' 'CCS2: 2x 117 kW, Type2: CLOSED'
# ...
